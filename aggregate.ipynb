# %%
import aggregator as ag

aggregator = ag.Aggregator(join_method='outer')
df = aggregator.merge_data()
df.to_csv('data/combined_data.csv')
# Out:
# merged climate data
# merged conflict data
# merged health data
# merged market data
# merged movement data

# %%
df
# Out:
#                  Region   District   CDI Month  Year   NDVI  Rainfall  \
# 0                 Awdal     Borama  1.05   Jan  2018  0.168     4.342
# 1                 Awdal       Baki  0.62   Jan  2018  0.132     6.065
# 2                 Awdal    Lughaye  0.63   Jan  2018  0.047     7.915
# 3                 Awdal     Zeylac  1.10   Jan  2018  0.052     8.121
# 4       Woqooyi Galbeed   Hargeysa  0.78   Jan  2018  0.000     2.247
# ...                 ...        ...   ...   ...   ...    ...       ...
# 328851      Middle Juba     Saakow   NaN   Dec  2014    NaN       NaN
# 328852       Lower Juba   Kismaayo   NaN   Dec  2014    NaN       NaN
# 328853       Lower Juba    Afmadow   NaN   Dec  2014    NaN       NaN
# 328854       Lower Juba  Badhaadhe   NaN   Dec  2014    NaN       NaN
# 328855       Lower Juba    Jamaame   NaN   Dec  2014    NaN       NaN
#
#         Water Price  Conflict Fatalities  Conflict Incidents  ...  \
# 0            4000.0                  0.0                 1.0  ...
# 1               NaN                  0.0                 0.0  ...
# 2               NaN                  0.0                 0.0  ...
# 3            6000.0                  0.0                 0.0  ...
# 4           11000.0                  0.0                 1.0  ...
# ...             ...                  ...                 ...  ...
# 328851          NaN                  NaN                 NaN  ...
# 328852          NaN                  NaN                 NaN  ...
# 328853          NaN                  NaN                 NaN  ...
# 328854          NaN                  NaN                 NaN  ...
# 328855          NaN                  NaN                 NaN  ...
#
#         Cost Min Basket  Goat Price  Goat to Cereal  Maize Price Rice Price  \
# 0           1,090,175.0     297,750            57.0        4,000      5,200
# 1                   NaN         NaN             NaN          NaN        NaN
# 2                   NaN     300,000            50.0          NaN      7,000
# 3           1,160,475.0     410,000            59.0        6,000      7,000
# 4           1,366,665.0     460,000            92.0        6,000      5,000
# ...                 ...         ...             ...          ...        ...
# 328851      2,382,650.0     670,000            85.0        7,900     16,000
# 328852      2,420,900.0     921,000           132.0        7,000     14,000
# 328853      2,281,766.7     786,800            66.0       12,000     16,000
# 328854              NaN         NaN             NaN          NaN        NaN
# 328855      2,220,950.0     823,000           125.0        6,600     15,800
#
#        Sorghum Price Wage Price Wage to Cereal Departures Arrivals
# 0              3,200     57,400           11.0        6.0    199.0
# 1                NaN        NaN            NaN        NaN     69.0
# 2              6,000     90,000           15.0      253.0     24.0
# 3              5,500    100,000           14.0        NaN     68.0
# 4              5,000     70,000           14.0      400.0    663.0
# ...              ...        ...            ...        ...      ...
# 328851           NaN     79,250           10.0        NaN      NaN
# 328852           NaN    120,000           17.0        NaN      NaN
# 328853         9,000     80,000            7.0        NaN      NaN
# 328854           NaN        NaN            NaN        NaN      NaN
# 328855           NaN     73,400           11.0        NaN      NaN
#
# [328856 rows x 24 columns]
