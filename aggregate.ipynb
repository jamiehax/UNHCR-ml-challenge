# %%
import aggregator as ag

aggregator = ag.Aggregator(join_method='outer')
aggregator.aggregate_climate()
# Out:
# Combined CDI CSVs
# Combined flood CSVs
# Combined NDVI CSVs
# Combined rainfall CSVs
# Combined water price CSVs
#                 Region   District   CDI Month  Year  River Level   NDVI  \
# 0                Awdal     Borama  1.05   Jan  2018          NaN  0.168
# 1                Awdal       Baki  0.62   Jan  2018          NaN  0.132
# 2                Awdal    Lughaye  0.63   Jan  2018          NaN  0.047
# 3                Awdal     Zeylac  1.10   Jan  2018          NaN  0.052
# 4      Woqooyi Galbeed   Hargeysa  0.78   Jan  2018          NaN  0.000
# ...                ...        ...   ...   ...   ...          ...    ...
# 21307      Middle Juba     Saakow   NaN   Jun  2003          NaN    NaN
# 21308       Lower Juba   Kismaayo   NaN   Jun  2003          NaN    NaN
# 21309       Lower Juba    Afmadow   NaN   Jun  2003          NaN    NaN
# 21310       Lower Juba  Badhaadhe   NaN   Jun  2003          NaN    NaN
# ...
